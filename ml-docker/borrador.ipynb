# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras as ks
from keras.layers import Dense

# %%
#Importamos el archivo csv
training = "./data/creditcard_2023.csv"
data_training = pd.read_csv(training)

# %%
#Dividimos nuestro csv en x e y para poder entrenar nuestro modelo
x = data_training.iloc[:,1:-1].values
y = data_training.iloc[:,-1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, shuffle=True)

# %%
model = ks.models.Sequential()

model.add(Dense(16, activation= 'relu'))
model.add(Dense(16, activation= 'relu'))
model.add(Dense(32, activation= 'sigmoid'))
model.add(Dense(1, activation = 'sigmoid'))


model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5, batch_size=60)
# Out:
# Epoch 1/5
# 7582/7582 [==============================] - 43s 6ms/step - loss: 0.0097 - accuracy: 0.9889
# Epoch 2/5
# 7582/7582 [==============================] - 39s 5ms/step - loss: 0.0070 - accuracy: 0.9922
# Epoch 3/5
# 7582/7582 [==============================] - 39s 5ms/step - loss: 0.0056 - accuracy: 0.9939
# Epoch 4/5
# 7582/7582 [==============================] - 39s 5ms/step - loss: 0.0048 - accuracy: 0.9947
# Epoch 5/5
# 7582/7582 [==============================] - 42s 6ms/step - loss: 0.0044 - accuracy: 0.9952

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('Precisión del modelo en los datos de prueba:', test_acc)
# Out:
# 3554/3554 - 10s - loss: 0.0043 - accuracy: 0.9951 - 10s/epoch - 3ms/step
# Precisión del modelo en los datos de prueba: 0.9951110482215881

# %%
def cambio_etiqueta(etiqueta_binaria):
    if etiqueta_binaria == 0:
        return "Verdadero"
    else:
        return "Fraudulento"

# %%
prob = model.predict(x_test)
umbral = 0.99
predicciones = (prob > umbral).astype(int)
predicciones_clase = [cambio_etiqueta(etiqueta_binaria) for etiqueta_binaria in predicciones]
print(predicciones_clase)
# Out:
# 3554/3554 [==============================] - 5s 1ms/step
# ['Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Verdadero', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fraudulento', 'Fraudulento', 'Fraudulento', 'Verdadero', 'Fr ...
